# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20640 rows x 9 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_data=x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13861    -117.27     34.50                 8.0       3567.0           543.0
# 20134    -118.90     34.40                16.0       2614.0           575.0
# 11497    -118.07     33.67                13.0       5126.0           711.0
# 19225    -122.72     38.48                23.0       2296.0           356.0
# 15834    -122.44     37.75                52.0       2082.0           425.0
# ...          ...       ...                 ...          ...             ...
# 10210    -117.92     33.88                32.0       1632.0           244.0
# 17475    -119.89     34.44                25.0       3160.0           507.0
# 3131     -117.98     35.10                 4.0        923.0           166.0
# 809      -122.04     37.62                35.0       1032.0           173.0
# 15405    -117.24     33.23                21.0       1718.0           308.0
#
#        population  households  median_income ocean_proximity  \
# 13861      1133.0       419.0         5.3733          INLAND
# 20134      1163.0       524.0         1.5781       <1H OCEAN
# 11497      2429.0       718.0         9.5268      NEAR OCEAN
# 19225       902.0       334.0         6.0298       <1H OCEAN
# 15834       801.0       411.0         4.2708        NEAR BAY
# ...           ...         ...            ...             ...
# 10210       575.0       235.0         5.3986       <1H OCEAN
# 17475      1514.0       523.0         5.0767      NEAR OCEAN
# 3131        352.0       135.0         4.5724          INLAND
# 809         453.0       176.0         6.3960        NEAR BAY
# 15405      1194.0       312.0         3.4359       <1H OCEAN
#
#        median_house_value
# 13861            302600.0
# 20134            134400.0
# 11497            437900.0
# 19225            289100.0
# 15834            368900.0
# ...                   ...
# 10210            318700.0
# 17475            271200.0
# 3131              84500.0
# 809              208500.0
# 15405            150900.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
sns.heatmap(train_data.corr(),annot=True)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_27280\3904379400.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True)
# <Axes: >

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13861    -117.27     34.50                 8.0       3567.0           543.0
# 20134    -118.90     34.40                16.0       2614.0           575.0
# 11497    -118.07     33.67                13.0       5126.0           711.0
# 19225    -122.72     38.48                23.0       2296.0           356.0
# 15834    -122.44     37.75                52.0       2082.0           425.0
# ...          ...       ...                 ...          ...             ...
# 10210    -117.92     33.88                32.0       1632.0           244.0
# 17475    -119.89     34.44                25.0       3160.0           507.0
# 3131     -117.98     35.10                 4.0        923.0           166.0
# 809      -122.04     37.62                35.0       1032.0           173.0
# 15405    -117.24     33.23                21.0       1718.0           308.0
#
#        population  households  median_income ocean_proximity  \
# 13861      1133.0       419.0         5.3733          INLAND
# 20134      1163.0       524.0         1.5781       <1H OCEAN
# 11497      2429.0       718.0         9.5268      NEAR OCEAN
# 19225       902.0       334.0         6.0298       <1H OCEAN
# 15834       801.0       411.0         4.2708        NEAR BAY
# ...           ...         ...            ...             ...
# 10210       575.0       235.0         5.3986       <1H OCEAN
# 17475      1514.0       523.0         5.0767      NEAR OCEAN
# 3131        352.0       135.0         4.5724          INLAND
# 809         453.0       176.0         6.3960        NEAR BAY
# 15405      1194.0       312.0         3.4359       <1H OCEAN
#
#        median_house_value
# 13861            302600.0
# 20134            134400.0
# 11497            437900.0
# 19225            289100.0
# 15834            368900.0
# ...                   ...
# 10210            318700.0
# 17475            271200.0
# 3131              84500.0
# 809              208500.0
# 15405            150900.0
#
# [16346 rows x 10 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity))

# %%
train_data=train_data.drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13861    -117.27     34.50                 8.0       3567.0           543.0
# 20134    -118.90     34.40                16.0       2614.0           575.0
# 11497    -118.07     33.67                13.0       5126.0           711.0
# 19225    -122.72     38.48                23.0       2296.0           356.0
# 15834    -122.44     37.75                52.0       2082.0           425.0
# ...          ...       ...                 ...          ...             ...
# 10210    -117.92     33.88                32.0       1632.0           244.0
# 17475    -119.89     34.44                25.0       3160.0           507.0
# 3131     -117.98     35.10                 4.0        923.0           166.0
# 809      -122.04     37.62                35.0       1032.0           173.0
# 15405    -117.24     33.23                21.0       1718.0           308.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13861      1133.0       419.0         5.3733            302600.0          0
# 20134      1163.0       524.0         1.5781            134400.0          1
# 11497      2429.0       718.0         9.5268            437900.0          0
# 19225       902.0       334.0         6.0298            289100.0          1
# 15834       801.0       411.0         4.2708            368900.0          0
# ...           ...         ...            ...                 ...        ...
# 10210       575.0       235.0         5.3986            318700.0          1
# 17475      1514.0       523.0         5.0767            271200.0          0
# 3131        352.0       135.0         4.5724             84500.0          0
# 809         453.0       176.0         6.3960            208500.0          0
# 15405      1194.0       312.0         3.4359            150900.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13861       1       0         0           0
# 20134       0       0         0           0
# 11497       0       0         0           1
# 19225       0       0         0           0
# 15834       0       0         1           0
# ...       ...     ...       ...         ...
# 10210       0       0         0           0
# 17475       0       0         0           1
# 3131        1       0         0           0
# 809         0       0         1           0
# 15405       0       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13861    -117.27     34.50                 8.0       3567.0           543.0
# 20134    -118.90     34.40                16.0       2614.0           575.0
# 11497    -118.07     33.67                13.0       5126.0           711.0
# 19225    -122.72     38.48                23.0       2296.0           356.0
# 15834    -122.44     37.75                52.0       2082.0           425.0
# ...          ...       ...                 ...          ...             ...
# 10210    -117.92     33.88                32.0       1632.0           244.0
# 17475    -119.89     34.44                25.0       3160.0           507.0
# 3131     -117.98     35.10                 4.0        923.0           166.0
# 809      -122.04     37.62                35.0       1032.0           173.0
# 15405    -117.24     33.23                21.0       1718.0           308.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13861      1133.0       419.0         5.3733            302600.0          0
# 20134      1163.0       524.0         1.5781            134400.0          1
# 11497      2429.0       718.0         9.5268            437900.0          0
# 19225       902.0       334.0         6.0298            289100.0          1
# 15834       801.0       411.0         4.2708            368900.0          0
# ...           ...         ...            ...                 ...        ...
# 10210       575.0       235.0         5.3986            318700.0          1
# 17475      1514.0       523.0         5.0767            271200.0          0
# 3131        352.0       135.0         4.5724             84500.0          0
# 809         453.0       176.0         6.3960            208500.0          0
# 15405      1194.0       312.0         3.4359            150900.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13861       1       0         0           0
# 20134       0       0         0           0
# 11497       0       0         0           1
# 19225       0       0         0           0
# 15834       0       0         1           0
# ...       ...     ...       ...         ...
# 10210       0       0         0           0
# 17475       0       0         0           1
# 3131        1       0         0           0
# 809         0       0         1           0
# 15405       0       0         0           0
#
# [16346 rows x 14 columns]

# %%
data.fillna(0,inplace=True)

# %%
y_train = train_data['median_house_value']
x_train = train_data.drop(['median_house_value'],axis=1)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13861    -117.27     34.50                 8.0       3567.0           543.0
# 20134    -118.90     34.40                16.0       2614.0           575.0
# 11497    -118.07     33.67                13.0       5126.0           711.0
# 19225    -122.72     38.48                23.0       2296.0           356.0
# 15834    -122.44     37.75                52.0       2082.0           425.0
# ...          ...       ...                 ...          ...             ...
# 10210    -117.92     33.88                32.0       1632.0           244.0
# 17475    -119.89     34.44                25.0       3160.0           507.0
# 3131     -117.98     35.10                 4.0        923.0           166.0
# 809      -122.04     37.62                35.0       1032.0           173.0
# 15405    -117.24     33.23                21.0       1718.0           308.0
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 13861      1133.0       419.0         5.3733          0       1       0
# 20134      1163.0       524.0         1.5781          1       0       0
# 11497      2429.0       718.0         9.5268          0       0       0
# 19225       902.0       334.0         6.0298          1       0       0
# 15834       801.0       411.0         4.2708          0       0       0
# ...           ...         ...            ...        ...     ...     ...
# 10210       575.0       235.0         5.3986          1       0       0
# 17475      1514.0       523.0         5.0767          0       0       0
# 3131        352.0       135.0         4.5724          0       1       0
# 809         453.0       176.0         6.3960          0       0       0
# 15405      1194.0       312.0         3.4359          1       0       0
#
#        NEAR BAY  NEAR OCEAN
# 13861         0           0
# 20134         0           0
# 11497         0           1
# 19225         0           0
# 15834         1           0
# ...         ...         ...
# 10210         0           0
# 17475         0           1
# 3131          0           0
# 809           1           0
# 15405         0           0
#
# [16346 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression

regression=LinearRegression()

regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(y_test)
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17593    -121.91     37.30                31.0       2095.0           427.0
# 20034    -119.02     36.07                39.0       1173.0           269.0
# 6181     -117.92     34.08                35.0       1897.0           311.0
# 13096    -121.30     38.51                19.0        822.0           134.0
# 16977    -122.31     37.57                31.0       2197.0           477.0
# ...          ...       ...                 ...          ...             ...
# 18323    -122.13     37.44                43.0       3004.0           440.0
# 10882    -117.90     33.71                16.0       1917.0           317.0
# 88       -122.27     37.80                10.0        105.0            42.0
# 11612    -118.04     33.80                33.0       2685.0           466.0
# 20445    -118.83     34.33                 6.0       6679.0          1164.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 17593       829.0       405.0         3.6563            344700.0          1
# 20034       702.0       232.0         1.6146             53100.0          0
# 6181        965.0       323.0         5.7039            199400.0          1
# 13096       457.0       133.0         4.1500            157500.0          0
# 16977      1193.0       394.0         4.6371            271100.0          0
# ...           ...         ...            ...                 ...        ...
# 18323      1088.0       427.0         9.1508            500001.0          0
# 10882      1324.0       351.0         6.2488            252000.0          1
# 88          125.0        39.0         0.9722            137500.0          0
# 11612      1359.0       476.0         5.0261            245100.0          1
# 20445      3196.0      1157.0         5.4493            242600.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 17593       0       0         0           0
# 20034       1       0         0           0
# 6181        0       0         0           0
# 13096       1       0         0           0
# 16977       0       0         0           1
# ...       ...     ...       ...         ...
# 18323       0       0         1           0
# 10882       0       0         0           0
# 88          0       0         1           0
# 11612       0       0         0           0
# 20445       0       0         0           0
#
# [4128 rows x 14 columns]

# %%
test_data.dropna(inplace=True)
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4089 entries, 17593 to 20445
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           4089 non-null   float64
#  1   latitude            4089 non-null   float64
#  2   housing_median_age  4089 non-null   float64
#  3   total_rooms         4089 non-null   float64
#  4   total_bedrooms      4089 non-null   float64
#  5   population          4089 non-null   float64
#  6   households          4089 non-null   float64
#  7   median_income       4089 non-null   float64
#  8   median_house_value  4089 non-null   float64
#  9   <1H OCEAN           4089 non-null   uint8
#  10  INLAND              4089 non-null   uint8
#  11  ISLAND              4089 non-null   uint8
#  12  NEAR BAY            4089 non-null   uint8
#  13  NEAR OCEAN          4089 non-null   uint8
# dtypes: float64(9), uint8(5)
# memory usage: 339.4 KB

# %%
y_test=test_data['median_house_value']
x_test=test_data.drop(['median_house_value'],axis=1)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4089 entries, 17593 to 20445
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           4089 non-null   float64
#  1   latitude            4089 non-null   float64
#  2   housing_median_age  4089 non-null   float64
#  3   total_rooms         4089 non-null   float64
#  4   total_bedrooms      4089 non-null   float64
#  5   population          4089 non-null   float64
#  6   households          4089 non-null   float64
#  7   median_income       4089 non-null   float64
#  8   <1H OCEAN           4089 non-null   uint8
#  9   INLAND              4089 non-null   uint8
#  10  ISLAND              4089 non-null   uint8
#  11  NEAR BAY            4089 non-null   uint8
#  12  NEAR OCEAN          4089 non-null   uint8
# dtypes: float64(8), uint8(5)
# memory usage: 307.5 KB

# %%
regression.score(x_test,y_test)
# Out:
# 0.6431103207046036

# %%
from sklearn.ensemble import RandomForestRegressor

forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.9383461552675926
